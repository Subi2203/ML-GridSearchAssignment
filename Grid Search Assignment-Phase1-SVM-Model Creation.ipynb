# %%
#importing the Libraries
import pandas as pd

# %%
#Reading the Dataset
dataset=pd.read_csv("insurance_pre.csv")

# %%
#Convert categorical(nominal or ordinal) data into numerical data and delete first column
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#Get the column names
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
#split into training set and test set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
#Convert the data into standardized data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test-sc.transform(X_test)
# Out:
#             age        bmi  children  sex_male  smoker_yes
# 578   51.105407  30.288630  1.067464 -0.023787    0.504670
# 610   46.462420  29.591808  1.067464  0.976766    0.504670
# 569   47.391018  38.990508  1.236590 -0.023787   -0.981493
# 1034  59.462783  37.156104  0.898339 -0.023787    0.504670
# 198   50.176810  20.088165  0.898339  0.976766    0.504670
# ...         ...        ...       ...       ...         ...
# 1261  28.819071  36.081487  1.067464 -0.023787    0.504670
# 494   22.318889  26.510680  1.574841 -0.023787   -0.981493
# 97    53.891199  37.072149  0.898339 -0.023787    0.504670
# 418   62.248575  37.810949  1.067464 -0.023787    0.504670
# 920   60.391381  25.922999  0.898339  0.976766    0.504670
#
# [402 rows x 5 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf', 'poly', 'sigmoid', 'linear'],'C':[10,100,1000,2000,3000],'gamma':['auto', 'scale']}
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
#fitting the model for grid search
grid.fit(X_train,Y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 113 out of 120 | elapsed:   25.7s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   25.8s finished
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='auto_deprecated', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning. Format is print(grid.best_params_)
result=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
#to view entire result table
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.112205      0.002881         0.012328    4.711456e-04      10
# 1        0.050072      0.033423         0.010661    2.052980e-03      10
# 2        0.044972      0.002942         0.012328    4.731719e-04      10
# 3        0.028648      0.003679         0.007997    2.157368e-03      10
# 4        0.039307      0.002866         0.012327    1.884301e-03      10
# 5        0.028648      0.002053         0.007329    4.710895e-04      10
# 6        0.042973      0.002158         0.013992    1.414112e-03      10
# 7        0.028649      0.001246         0.007663    4.709208e-04      10
# 8        0.041641      0.003088         0.011660    9.401559e-04     100
# 9        0.039308      0.003857         0.007996    1.414223e-03     100
# 10       0.040973      0.001413         0.013658    2.356685e-03     100
# 11       0.036977      0.005653         0.006662    4.714266e-04     100
# 12       0.041308      0.001699         0.013326    1.699862e-03     100
# 13       0.052303      0.015143         0.021986    1.696079e-02     100
# 14       0.050638      0.005243         0.012656    9.447710e-04     100
# 15       0.036643      0.005434         0.006330    4.714266e-04     100
# 16       0.054962      0.001411         0.012327    9.424597e-04    1000
# 17       0.053301      0.003856         0.007329    4.724943e-04    1000
# 18       0.048635      0.001698         0.013324    4.719356e-04    1000
# 19       0.053633      0.004107         0.006663    4.709772e-04    1000
# 20       0.053967      0.002942         0.012325    4.702468e-04    1000
# 21       0.079945      0.033330         0.007670    9.529684e-04    1000
# 22       0.053298      0.001247         0.012999    8.165689e-04    1000
# 23       0.050302      0.001699         0.006997    7.370010e-07    1000
# 24       0.060627      0.004496         0.012993    8.167295e-04    2000
# 25       0.076274      0.017596         0.007996    8.165351e-04    2000
# 26       0.048303      0.002866         0.013326    1.698942e-03    2000
# 27       0.060292      0.005436         0.007000    4.466064e-06    2000
# 28       0.057625      0.002052         0.011661    4.712020e-04    2000
# 29       0.092609      0.011891         0.007999    1.419450e-03    2000
# 30       0.048300      0.001889         0.012325    4.684488e-04    2000
# 31       0.061294      0.006842         0.006668    4.749387e-04    2000
# 32       0.071282      0.010867         0.010995    9.989584e-07    3000
# 33       0.136581      0.031012         0.007662    4.715398e-04    3000
# 34       0.047969      0.002826         0.012659    4.711456e-04    3000
# 35       0.092609      0.025807         0.005663    4.715390e-04    3000
# 36       0.070622      0.006795         0.011661    4.719349e-04    3000
# 37       0.116588      0.005732         0.007994    1.276523e-06    3000
# 38       0.045638      0.001246         0.012327    4.713707e-04    3000
# 39       0.091609      0.023682         0.005998    8.169243e-04    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.001622
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.045578
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.043747
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.379453
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.001551
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.044344
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043460
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.379453
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.280420
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.519516
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.497513
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.600824
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.280931
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.514963
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.495602
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.600824
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.713543
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.797601
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.405221
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.663978
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.713824
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.797154
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.385746
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.663978
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.794232
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822616
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.192402
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.710113
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.794443
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.821856
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.038754
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.710113
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.805659
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.824951
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.935044
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.710020
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.805853
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.825027
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.924846
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.710020
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.097907          -0.088465        -0.062665        0.043335
# 1           -0.050102          -0.039371        -0.014632        0.042800
# 2           -0.054054          -0.044185        -0.018164        0.043962
# 3            0.263743           0.270498         0.304565        0.053026
# 4           -0.097995          -0.088478        -0.062675        0.043395
# 5           -0.048766          -0.039184        -0.014535        0.041817
# 6           -0.053762          -0.044135        -0.018146        0.043738
# 7            0.263743           0.270498         0.304565        0.053026
# 8            0.159180           0.155842         0.198481        0.057956
# 9            0.445794           0.421048         0.462119        0.041824
# 10           0.425077           0.420930         0.447840        0.035165
# 11           0.573673           0.559680         0.578059        0.017081
# 12           0.158637           0.155756         0.198441        0.058341
# 13           0.450772           0.421861         0.462532        0.038908
# 14           0.426898           0.421539         0.448013        0.033721
# 15           0.573673           0.559680         0.578059        0.017081
# 16           0.671971           0.640038         0.675184        0.030094
# 17           0.795391           0.764729         0.785907        0.015002
# 18           0.336416           0.349444         0.363694        0.029842
# 19           0.673763           0.637674         0.658471        0.015239
# 20           0.671576           0.639937         0.675112        0.030267
# 21           0.795738           0.764963         0.785952        0.014853
# 22           0.319360           0.346897         0.350668        0.027233
# 23           0.673763           0.637674         0.658471        0.015239
# 24           0.780655           0.746425         0.773770        0.020115
# 25           0.813670           0.779845         0.805377        0.018419
# 26          -0.162949          -0.041406        -0.132252        0.065354
# 27           0.621857           0.634263         0.655411        0.039010
# 28           0.780342           0.746377         0.773721        0.020174
# 29           0.813718           0.779857         0.805144        0.018187
# 30          -0.046722          -0.043343        -0.042940        0.003266
# 31           0.621857           0.634263         0.655411        0.039010
# 32           0.800880           0.768195         0.791578        0.016649
# 33           0.814057           0.783380         0.807463        0.017600
# 34          -0.652358          -0.912173        -0.833192        0.128209
# 35           0.621851           0.632748         0.654873        0.039248
# 36           0.800723           0.768175         0.791584        0.016684
# 37           0.813966           0.783395         0.807463        0.017607
# 38          -1.126127          -0.940265        -0.997079        0.091467
# 39           0.621851           0.632748         0.654873        0.039248
#
#     rank_test_score
# 0                36
# 1                32
# 2                34
# 3                27
# 4                37
# 5                31
# 6                33
# 7                27
# 8                29
# 9                22
# 10               24
# 11               19
# 12               30
# 13               21
# 14               23
# 15               19
# 16               11
# 17                8
# 18               25
# 19               13
# 20               12
# 21                7
# 22               26
# 23               13
# 24                9
# 25                3
# 26               38
# 27               15
# 28               10
# 29                4
# 30               35
# 31               15
# 32                6
# 33                1
# 34               39
# 35               17
# 36                5
# 37                2
# 38               40
# 39               17

# %%
age=float(input("Age:"))
bmi=float(input("BMI:"))
children=float(input("Children:"))
sex_male=int(input("Sex Male 0 or 1:"))
smoker_yes=int(input("Smoker 0 or 1:"))
# Out:
# Age:45
# BMI:50
# Children:1
# Sex Male 0 or 1:1
# Smoker 0 or 1:1

# %%
y_pred=grid.predict([[age,bmi,children,sex_male,smoker_yes]])

# %%
print("Future_Prediction={}".format(y_pred))
# Out:
# Future_Prediction=[11784910.34755269]
